# %%
# !pip install -q \
    numpy \
    pandas \
    scikit-learn \
    matplotlib \
    tslearn \
    xgboost
# Out:
# [notice] A new release of pip is available: 24.0 -> 24.2
# [notice] To update, run: /Applications/Xcode.app/Contents/Developer/usr/bin/python3 -m pip install --upgrade pip

# %%
import pandas as pd
import os
import warnings

# 모든 경고를 무시하도록 설정
warnings.filterwarnings('ignore')

forecast = pd.read_csv(os.path.join("Data", "forecast.csv"), index_col=0)
weather = pd.read_csv(os.path.join("Data", "weather.csv"), index_col=0)

load    = pd.read_csv(os.path.join("Data", "load.csv"), index_col=0)

load = load.loc[[idx for idx in load.index if (int(idx[11:13]) >=7 and int(idx[11:13]) <= 20)]]

load_e  = load

# 테스트 대상일:13일
# test    = load.iloc[-24:]
# load_e  = load[ load.index <= "2023-08-13"]
# test    = load[load.index >= "2023-08-13"][:24]

merged_factor = weather.join(forecast)

selected_feature = ['지면온도(°C)', '기온(°C)', '풍속', '습도(%)', '남북바람성분', '1시간기온', '습도', '풍향', '동서바람성분']

merged_factor = merged_factor[selected_feature]
merged_factor = merged_factor.loc[[idx for idx in merged_factor.index if (int(idx[11:13]) >=7 and int(idx[11:13]) <= 20)]]
merged_factor['hour'] = [int(idx[11:13]) for idx in merged_factor.index if (int(idx[11:13]) >=7 and int(idx[11:13]) <= 20)]

# %% [markdown]
# # 부하 패턴 군집화

# %%
import numpy as np
from tslearn.clustering import TimeSeriesKMeans
import matplotlib.pyplot as plt
import pickle

def create_sequences_set(y, time_steps=24, n_days=1):
    yy, ys = [], []
    for i in range(len(y) - n_days * time_steps):
        yy.append(list(y[i:i + time_steps])+ [y[i + time_steps]])
        ys.append(y[i:i + time_steps])
    return yy, np.array(ys)

def create_sequences_data(X, y, time_steps=24):
    xx, yy =[], []
    for i in range(0, len(y), time_steps):
        xx.append(X[i:i+time_steps])
        yy.append(y[i:i+time_steps])
    
    return np.array(xx), np.array(yy)


k = 5

for name in load_e.columns:
    load_data = load_e[name]

    # 입출력 분리
    y = load_data  # 건물동 발전량

    # 시퀀스
    time_steps = 24
    _, seq_y = create_sequences_data(merged_factor, y, time_steps=time_steps)
    seq_y = np.array(seq_y).reshape(len(seq_y), time_steps)


    model = TimeSeriesKMeans(n_clusters=k, metric="dtw", verbose=0, max_iter=10, dtw_inertia=True, random_state=123, tol=0.001, n_jobs=-1, n_init=10)
    y_pred = model.fit_predict(seq_y)

    # 모델 저장
    with open(os.path.join("Data","model_kmeans", f'timeseries_kmeans_load_{name.replace("/", "")}.pkl'), 'wb') as f:
        pickle.dump(model, f)

    # 모델 불러오기
    with open(os.path.join("Data","model_kmeans", f'timeseries_kmeans_load_{name.replace("/", "")}.pkl'), 'rb') as f:
        loaded_model = pickle.load(f)

# %%
# # sz = y_pred.shape[0]
# sz = time_steps

# for yi in range(k):
    
#     # plt.subplot(10, 5, 1 + yi)
#     plt.figure(figsize=(8, 8))
#     for xx in seq_y[y_pred == yi]:
#         plt.plot(xx.ravel(), "k-", alpha=.2)
#     plt.plot(model.cluster_centers_[yi].ravel(), "r-")
#     plt.xlim(0, sz)
#     plt.ylim(0, 250)
#     plt.text(0.55, 0.85,'Cluster %d' % (yi + 1),
#              transform=plt.gca().transAxes)
#     if yi == 1:
#         plt.title("DBA $k$-means")

# %% [markdown]
# # xgb 모델 생성

# %%
from sklearn.preprocessing import MinMaxScaler, StandardScaler
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error, r2_score
import xgboost as xgb
import pickle
from sklearn.model_selection import GridSearchCV

# k = 

factor = merged_factor.copy()
factor = factor[factor.index <= "2023-08-30"]
factor.index = pd.to_datetime(factor.index) + pd.DateOffset(hours=24)

scaler_dict = {}

for name in load_e.columns:
    
    # 모델 불러오기
    with open(os.path.join("Data","model_kmeans", f'timeseries_kmeans_load_{name.replace("/", "")}.pkl'), 'rb') as f:
        loaded_model = pickle.load(f)

    # train용 load 데이터
    load_data = load_e[name]

    load_df = pd.DataFrame(load_data)
    fore_data = load_df[:-24].values
    load_df = load_df[load_df.index >= "2022-07-02"]
    load_df.index = pd.to_datetime(load_df.index)

    load_df_c = load_df.join(factor)
    load_df_c['fore'] = fore_data


    # 시계열 데이터로 만들기
    time_steps = 24
    _, seq_y = create_sequences_data(factor, load_data[:-time_steps], time_steps=time_steps)
    seq_y = np.array(seq_y).reshape(len(seq_y), time_steps)

    seq_pred = loaded_model.fit_predict(seq_y)

    # X = np.array(load_data[:24]).reshape(1,-1)      # 임시
    # cl_indice = loaded_model.predict(X)

    

    cl_list = []
    scaler_list = []


    for i in range(k):
        cl_indice = i
        a = seq_pred == i
        cl_ = np.where(a == True)[0].tolist()

        # 군집에 해당하는 시계열들의 인덱스 리스트
        cl_list.append(cl_)


        load_cl_sub = pd.DataFrame(columns=load_df_c.columns)

        # 군집별로 데이터프레임 추출 후 학습
        for ele in cl_list[int(cl_indice)]:
            si = ele * time_steps
            ei = (ele+1) * time_steps

            sub_df = load_df_c.iloc[si:ei]
            load_cl_sub = pd.concat([load_cl_sub, sub_df], axis=0)



        X = load_cl_sub.drop(columns=name)
        y = load_cl_sub[name]

        # 데이터 스케일링
        scaler = MinMaxScaler()
        scaled_X = scaler.fit_transform(X)

        y_scaler = StandardScaler()
        scaled_y = y_scaler.fit_transform(np.array(y).reshape(-1,1))
        scaler_list.append(y_scaler)
        # scaled_y = y


        X_train, X_test, y_train, y_test = train_test_split(scaled_X, scaled_y, test_size=0.2, random_state=42)

        

        # 하이퍼파라미터 그리드 설정
        param_grid = {
            'max_depth': [5, 7, 9],
            'learning_rate': [0.01, 0.1, 0.2],
            'n_estimators': [100, 200, 300],
            'gamma': [0, 0.2, 0.5]
        }

        xgb_model = xgb.XGBRegressor(objective='reg:squarederror', n_estimators=100, max_depth=5, learning_rate=0.1, verbosity=0)
        grid_search = GridSearchCV(xgb_model, param_grid, cv=3, scoring='r2', verbose=1)
        grid_search.fit(X_train, y_train)

        best_model = grid_search.best_estimator_

        y_pred = best_model.predict(X_test)

        # 모델 저장
        best_model.save_model(os.path.join("Data","model_xgb", f'xgb_load_{name.replace("/", "")}_{cl_indice}.json'))

        # 성능 평가 (평균 제곱 오차)
        mse = mean_squared_error(y_test, y_pred)
        print(f"col: {name}, Mean Squared Error: {mse}")
    
    scaler_dict[name] = scaler_list
# Out:
# Fitting 3 folds for each of 81 candidates, totalling 243 fits
# col: 전기전자컴퓨터공학동, Mean Squared Error: 0.007112862176534993
# Fitting 3 folds for each of 81 candidates, totalling 243 fits
# col: 전기전자컴퓨터공학동, Mean Squared Error: 0.0
# Fitting 3 folds for each of 81 candidates, totalling 243 fits
# col: 전기전자컴퓨터공학동, Mean Squared Error: 0.01047037752103525
# Fitting 3 folds for each of 81 candidates, totalling 243 fits
# col: 전기전자컴퓨터공학동, Mean Squared Error: 0.00649268753309244
# Fitting 3 folds for each of 81 candidates, totalling 243 fits
# col: 전기전자컴퓨터공학동, Mean Squared Error: 0.01626280910976633
# Fitting 3 folds for each of 81 candidates, totalling 243 fits
# col: 전기전자컴퓨터공학동, Mean Squared Error: 0.0
# Fitting 3 folds for each of 81 candidates, totalling 243 fits
# col: 전기전자컴퓨터공학동, Mean Squared Error: 0.01766308981724271
# Fitting 3 folds for each of 81 candidates, totalling 243 fits
# col: 전기전자컴퓨터공학동, Mean Squared Error: 0.01289554053301246
# Fitting 3 folds for each of 81 candidates, totalling 243 fits
# col: 전기전자컴퓨터공학동, Mean Squared Error: 0.02745904146262879
# Fitting 3 folds for each of 81 candidates, totalling 243 fits
# col: 전기전자컴퓨터공학동, Mean Squared Error: 0.006393593310527457
# Fitting 3 folds for each of 81 candidates, totalling 243 fits
# col: 전기전자컴퓨터공학동, Mean Squared Error: 0.07578229597644444
# Fitting 3 folds for each of 81 candidates, totalling 243 fits
# col: 전기전자컴퓨터공학동, Mean Squared Error: 0.024065001508763187
# Fitting 3 folds for each of 81 candidates, totalling 243 fits
# col: 전기전자컴퓨터공학동, Mean Squared Error: 0.0057432997824742715
# Fitting 3 folds for each of 81 candidates, totalling 243 fits
# col: 전기전자컴퓨터공학동, Mean Squared Error: 0.04883496003939407
# Fitting 3 folds for each of 81 candidates, totalling 243 fits
# col: 전기전자컴퓨터공학동, Mean Squared Error: 0.031946343759337
# Fitting 3 folds for each of 81 candidates, totalling 243 fits
# col: 신소재공학동, Mean Squared Error: 0.0
# Fitting 3 folds for each of 81 candidates, totalling 243 fits
# col: 신소재공학동, Mean Squared Error: 0.004105165346258193
# Fitting 3 folds for each of 81 candidates, totalling 243 fits
# col: 신소재공학동, Mean Squared Error: 0.003792409213312929
# Fitting 3 folds for each of 81 candidates, totalling 243 fits
# col: 신소재공학동, Mean Squared Error: 0.000351395321803619
# Fitting 3 folds for each of 81 candidates, totalling 243 fits
# col: 신소재공학동, Mean Squared Error: 0.011540108987677492
# Fitting 3 folds for each of 81 candidates, totalling 243 fits
# col: 신소재공학동, Mean Squared Error: 0.02292373658944853
# Fitting 3 folds for each of 81 candidates, totalling 243 fits
# col: 신소재공학동, Mean Squared Error: 0.0024794350239878598
# Fitting 3 folds for each of 81 candidates, totalling 243 fits
# col: 신소재공학동, Mean Squared Error: 0.04306277627950354
# Fitting 3 folds for each of 81 candidates, totalling 243 fits
# col: 신소재공학동, Mean Squared Error: 0.0038039569519482458
# Fitting 3 folds for each of 81 candidates, totalling 243 fits
# col: 신소재공학동, Mean Squared Error: 0.0318250386718644
# Fitting 3 folds for each of 81 candidates, totalling 243 fits
# col: 신소재공학동, Mean Squared Error: 0.011891492182996075
# Fitting 3 folds for each of 81 candidates, totalling 243 fits
# col: 신소재공학동, Mean Squared Error: 0.00454474344357513
# Fitting 3 folds for each of 81 candidates, totalling 243 fits
# col: 신소재공학동, Mean Squared Error: 0.005259599067961269
# Fitting 3 folds for each of 81 candidates, totalling 243 fits
# col: 신소재공학동, Mean Squared Error: 0.005154523296094765
# Fitting 3 folds for each of 81 candidates, totalling 243 fits
# col: 신소재공학동, Mean Squared Error: 0.0077867898404118275
# Fitting 3 folds for each of 81 candidates, totalling 243 fits
# col: 생명과학동, Mean Squared Error: 0.015469082148548164
# Fitting 3 folds for each of 81 candidates, totalling 243 fits
# col: 생명과학동, Mean Squared Error: 0.0
# Fitting 3 folds for each of 81 candidates, totalling 243 fits
# col: 생명과학동, Mean Squared Error: 0.024861547806912746
# Fitting 3 folds for each of 81 candidates, totalling 243 fits
# col: 생명과학동, Mean Squared Error: 0.04371407369106446
# Fitting 3 folds for each of 81 candidates, totalling 243 fits
# col: 생명과학동, Mean Squared Error: 0.08974902625761647
# Fitting 3 folds for each of 81 candidates, totalling 243 fits
# col: 생명과학동, Mean Squared Error: 0.011920112617849971
# Fitting 3 folds for each of 81 candidates, totalling 243 fits
# col: 생명과학동, Mean Squared Error: 0.010212187418038837
# Fitting 3 folds for each of 81 candidates, totalling 243 fits
# col: 생명과학동, Mean Squared Error: 0.05657747083503306
# Fitting 3 folds for each of 81 candidates, totalling 243 fits
# col: 생명과학동, Mean Squared Error: 0.01744702402292074
# Fitting 3 folds for each of 81 candidates, totalling 243 fits
# col: 생명과학동, Mean Squared Error: 0.022938348721553915
# Fitting 3 folds for each of 81 candidates, totalling 243 fits
# col: 생명과학동, Mean Squared Error: 0.03339828700648663
# Fitting 3 folds for each of 81 candidates, totalling 243 fits
# col: 생명과학동, Mean Squared Error: 0.036694363015465185
# Fitting 3 folds for each of 81 candidates, totalling 243 fits
# col: 생명과학동, Mean Squared Error: 0.08053852965589091
# Fitting 3 folds for each of 81 candidates, totalling 243 fits
# col: 생명과학동, Mean Squared Error: 0.027081114694458248
# Fitting 3 folds for each of 81 candidates, totalling 243 fits
# col: 생명과학동, Mean Squared Error: 0.02832652533073187
# Fitting 3 folds for each of 81 candidates, totalling 243 fits
# col: 기계공학동, Mean Squared Error: 0.02339706160918032
# Fitting 3 folds for each of 81 candidates, totalling 243 fits
# col: 기계공학동, Mean Squared Error: 0.0
# Fitting 3 folds for each of 81 candidates, totalling 243 fits
# col: 기계공학동, Mean Squared Error: 0.021388208139135115
# Fitting 3 folds for each of 81 candidates, totalling 243 fits
# col: 기계공학동, Mean Squared Error: 0
# Fitting 3 folds for each of 81 candidates, totalling 243 fits
# col: 대학C동, Mean Squared Error: 0.0
# Fitting 3 folds for each of 81 candidates, totalling 243 fits
# col: 대학C동, Mean Squared Error: 0.014064451503802844
# Fitting 3 folds for each of 81 candidates, totalling 243 fits
# col: 대학C동, Mean Squared Error: 0.0
# Fitting 3 folds for each of 81 candidates, totalling 243 fits
# col: 대학C동, Mean Squared Error: 0.008557459554794816
# Fitting 3 folds for each of 81 candidates, totalling 243 fits
# col: 대학C동, Mean Squared Error: 0.021050257969960247
# Fitting 3 folds for each of 81 candidates, totalling 243 fits
# col: 대학C동, Mean Squared Error: 0.02787410044532831
# Fitting 3 folds for each of 81 candidates, totalling 243 fits
# col: 대학C동, Mean Squared Error: 0.014145714274962569
# Fitting 3 folds for each of 81 candidates, totalling 243 fits
# col: 대학C동, Mean Squared Error: 0.06391402330471707
# Fitting 3 folds for each of 81 candidates, totalling 243 fits
# col: 대학C동, Mean Squared Error: 0.00482245410706225
# Fitting 3 folds for each of 81 candidates, totalling 243 fits
# col: 대학C동, Mean Squared Error: 0.005628171118379242
# Fitting 3 folds for each of 81 candidates, totalling 243 fits
# col: 대학C동, Mean Squared Error: 0.009459747150650795
# Fitting 3 folds for each of 81 candidates, totalling 243 fits
# col: 대학C동, Mean Squared Error: 0.009532074214272596
# Fitting 3 folds for each of 81 candidates, totalling 243 fits
# col: 대학C동, Mean Squared Error: 0.018300761549873975
# Fitting 3 folds for each of 81 candidates, totalling 243 fits
# col: 대학C동, Mean Squared Error: 0.05570506347875061
# Fitting 3 folds for each of 81 candidates, totalling 243 fits
# col: 대학C동, Mean Squared Error: 0.03191580308754288
# Fitting 3 folds for each of 81 candidates, totalling 243 fits
# col: 중앙연구기기센터, Mean Squared Error: 0.0
# Fitting 3 folds for each of 81 candidates, totalling 243 fits
# col: 중앙연구기기센터, Mean Squared Error: 0.010096235213385533
# Fitting 3 folds for each of 81 candidates, totalling 243 fits
# col: 중앙연구기기센터, Mean Squared Error: 0.014421089192438574
# Fitting 3 folds for each of 81 candidates, totalling 243 fits
# col: 중앙연구기기센터, Mean Squared Error: 0.021194142120539532
# Fitting 3 folds for each of 81 candidates, totalling 243 fits
# col: 중앙연구기기센터, Mean Squared Error: 0.04964054514750171
# Fitting 3 folds for each of 81 candidates, totalling 243 fits
# col: 중앙연구기기센터, Mean Squared Error: 0.023557711983213533
# Fitting 3 folds for each of 81 candidates, totalling 243 fits
# col: 중앙연구기기센터, Mean Squared Error: 0.08796124412812338
# Fitting 3 folds for each of 81 candidates, totalling 243 fits
# col: 중앙연구기기센터, Mean Squared Error: 0.021441091550747797
# Fitting 3 folds for each of 81 candidates, totalling 243 fits
# col: 중앙연구기기센터, Mean Squared Error: 0.03891501239428986
# Fitting 3 folds for each of 81 candidates, totalling 243 fits
# col: 중앙연구기기센터, Mean Squared Error: 0.020849293676218204
# Fitting 3 folds for each of 81 candidates, totalling 243 fits
# col: 중앙연구기기센터, Mean Squared Error: 0.008508377136334861
# Fitting 3 folds for each of 81 candidates, totalling 243 fits
# col: 중앙연구기기센터, Mean Squared Error: 0.010374303969887172
# Fitting 3 folds for each of 81 candidates, totalling 243 fits
# col: 중앙연구기기센터, Mean Squared Error: 0.0042964087705386
# Fitting 3 folds for each of 81 candidates, totalling 243 fits
# col: 중앙연구기기센터, Mean Squared Error: 0.028657929184407925
# Fitting 3 folds for each of 81 candidates, totalling 243 fits
# col: 중앙연구기기센터, Mean Squared Error: 0.030801151792722508
# Fitting 3 folds for each of 81 candidates, totalling 243 fits
# col: 대학A동, Mean Squared Error: 0.02596037767214728
# Fitting 3 folds for each of 81 candidates, totalling 243 fits
# col: 대학A동, Mean Squared Error: 0.0
# Fitting 3 folds for each of 81 candidates, totalling 243 fits
# col: 대학A동, Mean Squared Error: 0.009167233558447655
# Fitting 3 folds for each of 81 candidates, totalling 243 fits
# col: 대학A동, Mean Squared Error: 0.01240674344658117
# Fitting 3 folds for each of 81 candidates, totalling 243 fits
# col: 대학A동, Mean Squared Error: 0.024325375219254316
# Fitting 3 folds for each of 81 candidates, totalling 243 fits
# col: 대학A동, Mean Squared Error: 0.010095761716609144
# Fitting 3 folds for each of 81 candidates, totalling 243 fits
# col: 대학A동, Mean Squared Error: 0.02500806287968373
# Fitting 3 folds for each of 81 candidates, totalling 243 fits
# col: 대학A동, Mean Squared Error: 0.014989472787138122
# Fitting 3 folds for each of 81 candidates, totalling 243 fits
# col: 대학A동, Mean Squared Error: 0.0035857897330521487
# Fitting 3 folds for each of 81 candidates, totalling 243 fits
# col: 대학A동, Mean Squared Error: 0.010935498119495896
# Fitting 3 folds for each of 81 candidates, totalling 243 fits
# col: 대학A동, Mean Squared Error: 0.030174308897739303
# Fitting 3 folds for each of 81 candidates, totalling 243 fits
# col: 대학A동, Mean Squared Error: 0.02100940086301031
# Fitting 3 folds for each of 81 candidates, totalling 243 fits
# col: 대학A동, Mean Squared Error: 0.0026145937304121055
# Fitting 3 folds for each of 81 candidates, totalling 243 fits
# col: 대학A동, Mean Squared Error: 0.00655908487387132
# Fitting 3 folds for each of 81 candidates, totalling 243 fits
# col: 대학A동, Mean Squared Error: 0.02803663678211251
# Fitting 3 folds for each of 81 candidates, totalling 243 fits
# col: 다산빌딩, Mean Squared Error: 0.016506132437983042
# Fitting 3 folds for each of 81 candidates, totalling 243 fits
# col: 다산빌딩, Mean Squared Error: 0.0
# Fitting 3 folds for each of 81 candidates, totalling 243 fits
# col: 다산빌딩, Mean Squared Error: 0.009385566957274117
# Fitting 3 folds for each of 81 candidates, totalling 243 fits
# col: 다산빌딩, Mean Squared Error: 0.006049491569864555
# Fitting 3 folds for each of 81 candidates, totalling 243 fits
# col: 다산빌딩, Mean Squared Error: 0.024599434843517006
# Fitting 3 folds for each of 81 candidates, totalling 243 fits
# col: 다산빌딩, Mean Squared Error: 0.005716434291601995
# Fitting 3 folds for each of 81 candidates, totalling 243 fits
# col: 다산빌딩, Mean Squared Error: 0.01067116596283211
# Fitting 3 folds for each of 81 candidates, totalling 243 fits
# col: 다산빌딩, Mean Squared Error: 0.007057163126919087
# Fitting 3 folds for each of 81 candidates, totalling 243 fits
# col: 다산빌딩, Mean Squared Error: 0.0019315719578392246
# Fitting 3 folds for each of 81 candidates, totalling 243 fits
# col: 다산빌딩, Mean Squared Error: 0.01947326545260813
# Fitting 3 folds for each of 81 candidates, totalling 243 fits
# col: 다산빌딩, Mean Squared Error: 0.0075638432602421245
# Fitting 3 folds for each of 81 candidates, totalling 243 fits
# col: 다산빌딩, Mean Squared Error: 0.032256956445695005
# Fitting 3 folds for each of 81 candidates, totalling 243 fits
# col: 다산빌딩, Mean Squared Error: 0.008921039226350447
# Fitting 3 folds for each of 81 candidates, totalling 243 fits
# col: 다산빌딩, Mean Squared Error: 0.01987043333966083
# Fitting 3 folds for each of 81 candidates, totalling 243 fits
# col: 다산빌딩, Mean Squared Error: 0.02401638553136521
# Fitting 3 folds for each of 81 candidates, totalling 243 fits
# col: 산학협력연구동, Mean Squared Error: 0.005101040020521447
# Fitting 3 folds for each of 81 candidates, totalling 243 fits
# col: 산학협력연구동, Mean Squared Error: 0.017857121196458565
# Fitting 3 folds for each of 81 candidates, totalling 243 fits
# col: 산학협력연구동, Mean Squared Error: 0.017741871348003323
# Fitting 3 folds for each of 81 candidates, totalling 243 fits
# col: 산학협력연구동, Mean Squared Error: 0.04263879454112335
# Fitting 3 folds for each of 81 candidates, totalling 243 fits
# col: 산학협력연구동, Mean Squared Error: 0.011855819060466002
# Fitting 3 folds for each of 81 candidates, totalling 243 fits
# col: 산학협력연구동, Mean Squared Error: 0.04669037859204152
# Fitting 3 folds for each of 81 candidates, totalling 243 fits
# col: 산학협력연구동, Mean Squared Error: 0.018125770295041994
# Fitting 3 folds for each of 81 candidates, totalling 243 fits
# col: 산학협력연구동, Mean Squared Error: 0.013281019092241131
# Fitting 3 folds for each of 81 candidates, totalling 243 fits
# col: 산학협력연구동, Mean Squared Error: 0.020895564757735293
# Fitting 3 folds for each of 81 candidates, totalling 243 fits
# col: 산학협력연구동, Mean Squared Error: 0.0522579477803953
# Fitting 3 folds for each of 81 candidates, totalling 243 fits
# col: 산학협력연구동, Mean Squared Error: 0.04234300719941069
# Fitting 3 folds for each of 81 candidates, totalling 243 fits
# col: 산학협력연구동, Mean Squared Error: 0.06272300632445775
# Fitting 3 folds for each of 81 candidates, totalling 243 fits
# col: 산학협력연구동, Mean Squared Error: 0.006854416946210373
# Fitting 3 folds for each of 81 candidates, totalling 243 fits
# col: 산학협력연구동, Mean Squared Error: 0.05067308547653297
# Fitting 3 folds for each of 81 candidates, totalling 243 fits
# col: 산학협력연구동, Mean Squared Error: 0.08082351269761581

# %% [markdown]
# # 31 예측

# %%
import pickle
import xgboost as xgb
from sklearn.preprocessing import MinMaxScaler

RESULT = []

factor = merged_factor.copy()
factor = factor[factor.index >= "2023-08-30"]
factor = factor[:24]   #30일 데이터
factor.index = pd.to_datetime(factor.index) + pd.DateOffset(hours=24)   # join용 인덱스 맞추기

for name in load_e.columns:
    
    # 31일 없으므로 팩터로만 데이터프레임 만들기
    # test_value = test[name]
    test_df = factor.copy()
    # test_df[name] = test_value.values


    data30 = load_e[name][-time_steps:]   # 군집 분류 위한 30일 데이터


    # 모델 불러오기
    with open(os.path.join("Data","model_kmeans", f'timeseries_kmeans_load_{name.replace("/", "")}.pkl'), 'rb') as f:
        loaded_model = pickle.load(f)

    # 부하 모형 분류
    cl_indice = int(loaded_model.predict(np.array(data30).reshape(1,-1)))

    X_scaler = StandardScaler()
    y_scaler = scaler_dict[name][cl_indice]

    X = test_df
    # X = test_df.drop(columns=name)
    # y = test_df[name] #31일 없으므로 생략

    test_X = X_scaler.fit_transform(X)
    
    # xgb-k 모델 불러오기
    xgbk = xgb.Booster()
    xgbk.load_model(os.path.join("Data","model_xgb", f'xgb_load_{name.replace("/", "")}_{cl_indice}.json'))

    # 예측
    dtest = xgb.DMatrix(test_X)
    y_pred = xgbk.predict(dtest)

    output = y_scaler.inverse_transform(y_pred.reshape(1,-1))
    RESULT.append(output)

    # 성능 평가 (평균 제곱 오차) 31일 없어서 못함
    # mse = mean_squared_error(test_y, y_pred)
    # print(f"Mean Squared Error: {mse}")

# %%
result = np.zeros((1,time_steps))
for v in RESULT:
    result = result + v

pd.DataFrame(result.reshape(24,1), columns=["load"]).to_csv(os.path.join("result", "LOAD_RESULT.csv"))

# %%
result_ = result.tolist()[0]
# test_ = test.sum(axis=1)

plt.xlabel('t')
plt.ylabel('load')
plt.xticks(ticks=[i for i in range(time_steps)], labels=[i for i in range(time_steps)])

# plt.plot(test_, label="Actual Load")
plt.plot(result_, label="Pred. Load")

plt.legend()
